# %% [markdown]
# # 5. Importing Libraries and Visualizing Data
#
# You can import libraries and visualize data directly in your notebook.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot([1, 2, 3], [4, 5, 6])
plt.title('Sample Plot')
plt.show()
