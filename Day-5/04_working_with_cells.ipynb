# %% [markdown]
# # 4. Working with Cells
#
# You can use **code cells** to run Python code and **Markdown cells** to add formatted text.

# %%
# This is a code cell
print("Hello, Jupyter!")

# %% [markdown]
# ## This is a Markdown cell
# **Bold text**, *italic*, and `inline code`
